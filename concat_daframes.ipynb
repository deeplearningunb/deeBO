# %%
# Install this to load the binary dataframe file
#
#!!pip install pickle-mixin

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pickle import Pickler, Unpickler

# %% [markdown]
# ## Lendo os CSVs

# %%
# Method to load df
def get_samples(name):
    df = Unpickler(open('./' + name, 'rb')).load()
    return df

# %%
def read_data(year):
    return pd.read_csv('./crime-data-in-brazil/BO_'+ year +'.csv')

# %%
#This may take a while...

# ds_2007_1 = read_data('2007_1')
# ds_2007_2 = read_data('2007_2')
# ds_2008_1 = read_data('2008_1')
# ds_2008_2 = read_data('2008_2')
# ds_2009_1 = read_data('2009_1')
# ds_2009_2 = read_data('2009_2')
# ds_2007_1 = ds_2007_1[['ANO', 'MES', 'RUBRICA', 'LATITUDE', 'LONGITUDE', 'LOGRADOURO']]
# ds_2007_2 = ds_2007_2[['ANO', 'MES', 'RUBRICA', 'LATITUDE', 'LONGITUDE', 'LOGRADOURO']]
# ds_2008_1 = ds_2008_1[['ANO', 'MES', 'RUBRICA', 'LATITUDE', 'LONGITUDE', 'LOGRADOURO']]
# ds_2008_2 = ds_2008_2[['ANO', 'MES', 'RUBRICA', 'LATITUDE', 'LONGITUDE', 'LOGRADOURO']]
# ds_2009_1 = ds_2009_1[['ANO', 'MES', 'RUBRICA', 'LATITUDE', 'LONGITUDE', 'LOGRADOURO']]
# ds_2009_2 = ds_2009_2[['ANO', 'MES', 'RUBRICA', 'LATITUDE', 'LONGITUDE', 'LOGRADOURO']]
# frames = [ds_2007_1, ds_2007_2, ds_2008_1,ds_2008_2, ds_2009_1 ,ds_2009_2]
# result7_9 = pd.concat(frames)
# filename = './result7_9.sav'
# f = open(filename, 'wb')
# Pickler(f).dump(result7_9)
# f.close()

# %%
# ds_2010_1 = read_data('2010_1')
# ds_2010_2 = read_data('2010_2')
# ds_2011_1 = read_data('2011_1')
# ds_2011_2 = read_data('2011_2')
# ds_2012_1 = read_data('2012_1')
# ds_2012_2 = read_data('2012_2')
# ds_2010_1 = ds_2010_1[['ANO', 'MES', 'RUBRICA', 'LATITUDE', 'LONGITUDE', 'LOGRADOURO']]
# ds_2010_2 = ds_2010_2[['ANO', 'MES', 'RUBRICA', 'LATITUDE', 'LONGITUDE', 'LOGRADOURO']]
# ds_2011_1 = ds_2011_1[['ANO', 'MES', 'RUBRICA', 'LATITUDE', 'LONGITUDE', 'LOGRADOURO']]
# ds_2011_2 = ds_2011_2[['ANO', 'MES', 'RUBRICA', 'LATITUDE', 'LONGITUDE', 'LOGRADOURO']]
# ds_2012_1 = ds_2012_1[['ANO', 'MES', 'RUBRICA', 'LATITUDE', 'LONGITUDE', 'LOGRADOURO']]
# ds_2012_2 = ds_2012_2[['ANO', 'MES', 'RUBRICA', 'LATITUDE', 'LONGITUDE', 'LOGRADOURO']]
# frames = [ds_2010_1, ds_2010_2, ds_2011_1,ds_2011_2, ds_2012_1 ,ds_2012_2]
# result10_12 = pd.concat(frames)
# filename = './result10_12.sav'
# f = open(filename, 'wb')
# Pickler(f).dump(result10_12)
# f.close()

# %%
# ds_2013_1 = read_data('2013_1')
# ds_2013_2 = read_data('2013_2')
# ds_2014_1 = read_data('2014_1')
# ds_2014_2 = read_data('2014_2')
# ds_2015 = read_data('2015')
# ds_2016 = read_data('2016')
# ds_2013_1 = ds_2013_1[['ANO', 'MES', 'RUBRICA', 'LATITUDE', 'LONGITUDE', 'LOGRADOURO']]
# ds_2013_2 = ds_2013_2[['ANO', 'MES', 'RUBRICA', 'LATITUDE', 'LONGITUDE', 'LOGRADOURO']]
# ds_2014_1 = ds_2014_1[['ANO', 'MES', 'RUBRICA', 'LATITUDE', 'LONGITUDE', 'LOGRADOURO']]
# ds_2014_2 = ds_2014_2[['ANO', 'MES', 'RUBRICA', 'LATITUDE', 'LONGITUDE', 'LOGRADOURO']]
# ds_2015 = ds_2015[['ANO', 'MES', 'RUBRICA', 'LATITUDE', 'LONGITUDE', 'LOGRADOURO']]
# ds_2016 = ds_2016[['ANO', 'MES', 'RUBRICA', 'LATITUDE', 'LONGITUDE', 'LOGRADOURO']]
# frames = [ds_2013_1, ds_2013_2, ds_2014_1,ds_2014_2, ds_2015 ,ds_2016]
# result13_16 = pd.concat(frames)
# filename = './result13_16.sav'
# f = open(filename, 'wb')
# Pickler(f).dump(result13_16)
# f.close()

# %%
# NÃO DEU PARA RODAR APENAS POR FALTA DE MEMÓRIA


# result7_9 = get_samples('result7_9.sav')
# result10_12 = get_samples('result10_12.sav')
# result13_16 = get_samples('result13_16.sav')
# total_df = pd.concat([result7_9, result10_12, result13_16])
# filename = './total_df.sav'
# f = open(filename, 'wb')
# Pickler(f).dump(total_df)
# f.close()
# total_df.shape

# %% [markdown]
# ## Trabalhando apenas com anos de 2010 a 2016 por falta de memória
# ### os anos de 2007 a 2009 serão adicionados posteriormente

# %%
result10_12 = get_samples('result10_12.sav')

# %%
result10_12.shape
# Out:
# (4894046, 6)

# %%
result10_12.head()
# Out:
#     ANO  MES                                            RUBRICA LATITUDE  \
# 0  2010    1                 Furto qualificado (art. 155, §4o.)      NaN
# 1  2010    1  Lesão corporal culposa na direção de veículo a...      NaN
# 2  2010    1  Lesão corporal culposa na direção de veículo a...      NaN
# 3  2010    1                 Furto qualificado (art. 155, §4o.)      NaN
# 4  2010    1                                   Furto (art. 155)      NaN
#
#   LONGITUDE                                LOGRADOURO
# 0       NaN  R ALBANO FRAGOSO
# 1       NaN  AV JABAQUARA
# 2       NaN  AV JABAQUARA
# 3       NaN  R DOMINGOS AGOSTIN
# 4       NaN  R DO TATUAPE

# %%
result10_12['RUBRICA'].unique()
# Out:
# array(['Furto qualificado (art. 155, §4o.)',
#        'Lesão corporal culposa na direção de veículo automotor (Art. 303)',
#        'Furto (art. 155)', 'Lesão corporal (art. 129)',
#        'Roubo (art. 157)', 'Lesão corporal (art 129 § 9º)',
#        'Lesão corporal culposa (art. 129. §6o.)',
#        'Homicídio simples (art. 121)',
#        'Drogas sem autorização ou em desacordo (Art.33, caput)',
#        'Homicídio culposo na direção de veículo automotor (Art. 302)',
#        'Estupro (art.213)',
#        'Lesão corporal de natureza GRAVE (art. 129, §1o.)',
#        'Homicídio culposo (art. 121, §3o.)',
#        'Estupro de vulneravel (art.217-A)',
#        'Homicídio qualificado (art. 121, §2o.)',
#        'Furto de coisa comum (art. 156)',
#        "Lesão corporal  de natureza 'GRAVÍSSIMA' (art. 129, §2o.)",
#        'Tráfico de entorpecente (Art. 12)',
#        'Lesão corporal seguida de morte (art. 129, §3o.)',
# ...

# %%
#transformando data em uma coluna só
result10_12['DATA'] = pd.to_datetime(dict(year=result10_12.ANO, month=result10_12.MES, day=1))
result10_12 = result10_12.sort_values(by='DATA')
#tratando dado categórico do tipo de crime
result10_12 = pd.get_dummies(result10_12, columns=['RUBRICA'])
# #Renomeando algumas colunas para diminuir seus nomes
# result10_12.rename(columns={
#        'RUBRICA_Drogas sem autorização ou em desacordo (Art.33, caput)' : 'RUBRICA_Drogas (Art.33, caput)',
#        'RUBRICA_Lesão corporal culposa na direção de veículo automotor (Art. 303)': 'RUBRICA_Lesão corp culposa/veículo(Art. 303)',
#        'RUBRICA_A.I.-Drogas sem autorização ou em desacordo (Art.33, caput)':'RUBRICA_A.I.-Drogas (Art.33, caput)' ,
#        'RUBRICA_Homicídio culposo na direção de veículo automotor (Art. 302)': 'RUBRICA_Homicídio culposo/veículo(Art. 302)',
#        'RUBRICA_Oferecer droga a pessoa de seu relacionamento (Art.33,§3º)': 'RUBRICA_Oferecer droga(Art.33,§3º)' ,
#        'RUBRICA_A.I.-Lesão corporal culposa na direção de veículo automotor (Art. 303)': 'RUBRICA_A.I.-Lesão corp/veículo(Art. 303)',
#        'RUBRICA_Lesão corporal de natureza GRAVE (art. 129, §1o.)': 'RUBRICA_Lesão corporal GRAVE (art. 129, §1o.)',
#        'RUBRICA_A.I.-Oferecer droga a pessoa de seu relacionamento (Art.33,§3º)': 'RUBRICA_A.I.-Oferecer droga (Art.33,§3º)',
#        'RUBRICA_A.I.-Lesão corporal de natureza GRAVE (art. 129, §1o.)': 'RUBRICA_A.I.-Lesão corp. GRAVE (art. 129, §1o.)',
#        'RUBRICA_A.I.-Homicídio culposo na direção de veículo automotor (Art. 302)': 'RUBRICA_A.I.-Homicídio culp. veículo(Art. 302)',
#        'RUBRICA_Induzir, instigar ou auxiliar alguém ao uso indevido de droga(Art.33,§2º)': 'RUBRICA_Induzir uso de droga(Art.33,§2º)',
#        "RUBRICA_Lesão corporal  de natureza 'GRAVÍSSIMA' (art. 129, §2o.)": 'RUBRICA_Lesão corp GRAVÍSSIMA (art. 129, §2o.)',
#        "RUBRICA_A.I.-Lesão corporal  de natureza 'GRAVÍSSIMA' (art. 129, §2o.)": "RUBRICA_A.I.-Lesão corp'GRAVÍSSIMA' (art. 129, §2o.)"
# }, inplace=True)
result10_12.head()
# Out:
#          ANO  MES LATITUDE LONGITUDE  \
# 0       2010    1      NaN       NaN
# 573017  2010    1      NaN       NaN
# 573003  2010    1      NaN       NaN
# 573002  2010    1      NaN       NaN
# 573001  2010    1      NaN       NaN
#
#                                       LOGRADOURO       DATA  \
# 0       R ALBANO FRAGOSO                         2010-01-01
# 573017  AVENIDA DOS AUTONOMISTAS                 2010-01-01
# 573003  R APIAI MIRIM                            2010-01-01
# 573002  R LIZARDA                                2010-01-01
# 573001  R LIZARDA                                2010-01-01
#
#         RUBRICA_A.I.-Estupro de vulneravel (art.217-A)  \
# 0                                                    0
# 573017                                               0
# 573003                                               0
# 573002                                               0
# 573001                                               0
#
# ...

# %%
## deixando em df_crimes apenas as informações de RUBRICA
df_crimes = result10_12.drop(columns = ['DATA', 'ANO', 'MES', 'LATITUDE', 'LONGITUDE','LOGRADOURO'])
columns = list(df_crimes)
## contanto crimes e agrupando por data
df = pd.DataFrame({'DATA': result10_12.DATA.unique()})
for i in columns:
    df[i] = result10_12[i].groupby(result10_12.DATA).agg('sum').values
df
# Out:
#          DATA  RUBRICA_A.I.-Estupro de vulneravel (art.217-A)  \
# 0  2010-01-01                                               7
# 1  2010-02-01                                               0
# 2  2010-03-01                                               0
# 3  2010-04-01                                               0
# 4  2010-05-01                                               0
# 5  2010-06-01                                               0
# 6  2010-07-01                                               0
# 7  2010-08-01                                               0
# 8  2010-09-01                                               0
# 9  2010-10-01                                               3
# 10 2010-11-01                                               0
# 11 2010-12-01                                               0
# 12 2011-01-01                                               4
# 13 2011-02-01                                               3
# ...

# %%
list(df)
# Out:
# ['DATA',
#  'RUBRICA_A.I.-Estupro de vulneravel (art.217-A)',
#  'RUBRICA_A.I.-Lesão corporal (art. 129)',
#  'RUBRICA_Drogas sem autorização ou em desacordo (Art.33, caput)',
#  'RUBRICA_Estupro (art.213)',
#  'RUBRICA_Estupro de vulneravel (art.217-A)',
#  'RUBRICA_Furto (art. 155)',
#  'RUBRICA_Furto de coisa comum (art. 156)',
#  'RUBRICA_Furto qualificado (art. 155, §4o.)',
#  'RUBRICA_Homicídio culposo (art. 121, §3o.)',
#  'RUBRICA_Homicídio culposo na direção de veículo automotor (Art. 302)',
#  'RUBRICA_Homicídio qualificado (art. 121, §2o.)',
#  'RUBRICA_Homicídio simples (art. 121)',
#  'RUBRICA_Induzir, instigar ou auxiliar alguém ao uso indevido de droga(Art.33,§2º)',
#  "RUBRICA_Lesão corporal  de natureza 'GRAVÍSSIMA' (art. 129, §2o.)",
#  'RUBRICA_Lesão corporal (art 129 § 9º)',
#  'RUBRICA_Lesão corporal (art. 129)',
#  'RUBRICA_Lesão corporal culposa (art. 129. §6o.)',
#  'RUBRICA_Lesão corporal culposa na direção de veículo automotor (Art. 303)',
# ...

# %%
##################################################################
#
#
####   APENAS PARA 2010 A 2012
#
#
################################################################


#Generalizando alguns crimes para diminuição da complexidade das análises


#Generalizando alguns crimes para diminuição da complexidade das análises

df['FURTO'] = df[['RUBRICA_Furto (art. 155)',
                         'RUBRICA_Furto de coisa comum (art. 156)',
                         'RUBRICA_Furto qualificado (art. 155, §4o.)',]].sum(axis=1)

df['ROUBO'] = df[['RUBRICA_Roubo (art. 157)',]].sum(axis=1)

df['HOMICÍDIO'] = df[['RUBRICA_Homicídio culposo (art. 121, §3o.)',
                         'RUBRICA_Homicídio culposo na direção de veículo automotor (Art. 302)',
                         'RUBRICA_Homicídio qualificado (art. 121, §2o.)',
                         'RUBRICA_Homicídio simples (art. 121)',]].sum(axis=1)

df['LESAO CORPORAL'] = df[['RUBRICA_A.I.-Lesão corporal (art. 129)',
                          "RUBRICA_Lesão corporal  de natureza 'GRAVÍSSIMA' (art. 129, §2o.)",
                         'RUBRICA_Lesão corporal (art 129 § 9º)',
                         'RUBRICA_Lesão corporal (art. 129)',
                         'RUBRICA_Lesão corporal culposa (art. 129. §6o.)',
                         'RUBRICA_Lesão corporal culposa na direção de veículo automotor (Art. 303)',
                         'RUBRICA_Lesão corporal de natureza GRAVE (art. 129, §1o.)',
                         'RUBRICA_Lesão corporal seguida de morte (art. 129, §3o.)',]].sum(axis=1)

df['ESTUPRO'] = df[['RUBRICA_A.I.-Estupro de vulneravel (art.217-A)',
                   'RUBRICA_Estupro (art.213)',
                         'RUBRICA_Estupro de vulneravel (art.217-A)',]].sum(axis=1)

df['TRÁFICO'] = df[[ 'RUBRICA_Drogas sem autorização ou em desacordo (Art.33, caput)',
                         'RUBRICA_Induzir, instigar ou auxiliar alguém ao uso indevido de droga(Art.33,§2º)',
                         'RUBRICA_Oferecer droga a pessoa de seu relacionamento (Art.33,§3º)',
                         'RUBRICA_Porte de entorpecente (Art. 16)',
                         'RUBRICA_Porte de objeto destinado à fabricação de entorpecente (Art. 13)',
                         'RUBRICA_Tráfico de entorpecente (Art. 12)']].sum(axis=1)

df = df.drop(columns = ['RUBRICA_A.I.-Estupro de vulneravel (art.217-A)',
 'RUBRICA_A.I.-Lesão corporal (art. 129)',
 'RUBRICA_Drogas sem autorização ou em desacordo (Art.33, caput)',
 'RUBRICA_Estupro (art.213)',
 'RUBRICA_Estupro de vulneravel (art.217-A)',
 'RUBRICA_Furto (art. 155)',
 'RUBRICA_Furto de coisa comum (art. 156)',
 'RUBRICA_Furto qualificado (art. 155, §4o.)',
 'RUBRICA_Homicídio culposo (art. 121, §3o.)',
 'RUBRICA_Homicídio culposo na direção de veículo automotor (Art. 302)',
 'RUBRICA_Homicídio qualificado (art. 121, §2o.)',
 'RUBRICA_Homicídio simples (art. 121)',
 'RUBRICA_Induzir, instigar ou auxiliar alguém ao uso indevido de droga(Art.33,§2º)',
 "RUBRICA_Lesão corporal  de natureza 'GRAVÍSSIMA' (art. 129, §2o.)",
 'RUBRICA_Lesão corporal (art 129 § 9º)',
 'RUBRICA_Lesão corporal (art. 129)',
 'RUBRICA_Lesão corporal culposa (art. 129. §6o.)',
 'RUBRICA_Lesão corporal culposa na direção de veículo automotor (Art. 303)',
 'RUBRICA_Lesão corporal de natureza GRAVE (art. 129, §1o.)',
 'RUBRICA_Lesão corporal seguida de morte (art. 129, §3o.)',
 'RUBRICA_Oferecer droga a pessoa de seu relacionamento (Art.33,§3º)',
 'RUBRICA_Porte de entorpecente (Art. 16)',
 'RUBRICA_Porte de objeto destinado à fabricação de entorpecente (Art. 13)',
 'RUBRICA_Roubo (art. 157)',
 'RUBRICA_Tráfico de entorpecente (Art. 12)'])

filename = './df_10_12.sav'
f = open(filename, 'wb')
Pickler(f).dump(df)
f.close()

# %%
##################################################################
#
#
####   APENAS PARA 2013 A 2015
#
#
################################################################


#Generalizando alguns crimes para diminuição da complexidade das análises

df['FURTO'] = df[[ 'RUBRICA_A.I.-Furto (art. 155)',
                     'RUBRICA_A.I.-Furto de coisa comum (art. 156)',
                     'RUBRICA_A.I.-Furto qualificado (art. 155, §4o.)',
                     'RUBRICA_Furto (art. 155)',
                     'RUBRICA_Furto de coisa comum (art. 156)',
                     'RUBRICA_Furto qualificado (art. 155, §4o.)',]].sum(axis=1)

df['ROUBO'] = df[['RUBRICA_A.I.-Roubo (art. 157)',
                  'RUBRICA_Roubo (art. 157)']].sum(axis=1)

df['HOMICÍDIO'] = df[[ 'RUBRICA_A.I.-Homicídio culposo (art. 121, §3o.)',
 'RUBRICA_A.I.-Homicídio culposo na direção de veículo automotor (Art. 302)',
 'RUBRICA_A.I.-Homicídio qualificado (art. 121, §2o.)',
 'RUBRICA_A.I.-Homicídio simples (art. 121)',
 'RUBRICA_Homicídio culposo (art. 121, §3o.)',
 'RUBRICA_Homicídio culposo na direção de veículo automotor (Art. 302)',
 'RUBRICA_Homicídio qualificado (art. 121, §2o.)',
 'RUBRICA_Homicídio simples (art. 121)',]].sum(axis=1)

df['LESAO CORPORAL'] = df[[ "RUBRICA_A.I.-Lesão corporal  de natureza 'GRAVÍSSIMA' (art. 129, §2o.)",
                             'RUBRICA_A.I.-Lesão corporal (art 129 § 9º)',
                             'RUBRICA_A.I.-Lesão corporal (art. 129)',
                             'RUBRICA_A.I.-Lesão corporal culposa (art. 129. §6o.)',
                             'RUBRICA_A.I.-Lesão corporal culposa na direção de veículo automotor (Art. 303)',
                             'RUBRICA_A.I.-Lesão corporal de natureza GRAVE (art. 129, §1o.)',
                                                       "RUBRICA_Lesão corporal  de natureza 'GRAVÍSSIMA' (art. 129, §2o.)",
                             'RUBRICA_Lesão corporal (art 129 § 9º)',
                             'RUBRICA_Lesão corporal (art. 129)',
                             'RUBRICA_Lesão corporal culposa (art. 129. §6o.)',
                             'RUBRICA_Lesão corporal culposa na direção de veículo automotor (Art. 303)',
                             'RUBRICA_Lesão corporal de natureza GRAVE (art. 129, §1o.)',
                             'RUBRICA_Lesão corporal seguida de morte (art. 129, §3o.)']].sum(axis=1)

df['ESTUPRO'] = df[['RUBRICA_A.I.-Estupro de vulneravel (art.217-A)',
                    'RUBRICA_Estupro (art.213)',
                     'RUBRICA_Estupro de vulneravel (art.217-A)',]].sum(axis=1)

df['TRÁFICO'] = df[['RUBRICA_A.I.-Drogas sem autorização ou em desacordo (Art.33, caput)',
                   'RUBRICA_A.I.-Induzir, instigar ou auxiliar alguém ao uso indevido de droga(Art.33,§2º)',
                    'RUBRICA_A.I.-Oferecer droga a pessoa de seu relacionamento (Art.33,§3º)',
                    'RUBRICA_A.I.-Porte de entorpecente (Art. 16)',
                    'RUBRICA_A.I.-Porte de objeto destinado à fabricação de entorpecente (Art. 13)',
                    'RUBRICA_A.I.-Tráfico de entorpecente (Art. 12)',
                    'RUBRICA_Drogas sem autorização ou em desacordo (Art.33, caput)',
                    'RUBRICA_Induzir, instigar ou auxiliar alguém ao uso indevido de droga(Art.33,§2º)',
                    'RUBRICA_Oferecer droga a pessoa de seu relacionamento (Art.33,§3º)',
                    'RUBRICA_Porte de entorpecente (Art. 16)',
                    'RUBRICA_Tráfico de entorpecente (Art. 12)']].sum(axis=1)

##################################################################
#
#
####   APENAS PARA 2013 A 2015
#
#
################################################################

df = df.drop(columns = ['RUBRICA_A.I.-Drogas sem autorização ou em desacordo (Art.33, caput)',
                         'RUBRICA_A.I.-Estupro de vulneravel (art.217-A)',
                         'RUBRICA_A.I.-Furto (art. 155)',
                         'RUBRICA_A.I.-Furto de coisa comum (art. 156)',
                         'RUBRICA_A.I.-Furto qualificado (art. 155, §4o.)',
                         'RUBRICA_A.I.-Homicídio culposo (art. 121, §3o.)',
                         'RUBRICA_A.I.-Homicídio culposo na direção de veículo automotor (Art. 302)',
                         'RUBRICA_A.I.-Homicídio qualificado (art. 121, §2o.)',
                         'RUBRICA_A.I.-Homicídio simples (art. 121)',
                         'RUBRICA_A.I.-Induzir, instigar ou auxiliar alguém ao uso indevido de droga(Art.33,§2º)',
                         "RUBRICA_A.I.-Lesão corporal  de natureza 'GRAVÍSSIMA' (art. 129, §2o.)",
                         'RUBRICA_A.I.-Lesão corporal (art 129 § 9º)',
                         'RUBRICA_A.I.-Lesão corporal (art. 129)',
                         'RUBRICA_A.I.-Lesão corporal culposa (art. 129. §6o.)',
                         'RUBRICA_A.I.-Lesão corporal culposa na direção de veículo automotor (Art. 303)',
                         'RUBRICA_A.I.-Lesão corporal de natureza GRAVE (art. 129, §1o.)',
                         'RUBRICA_A.I.-Oferecer droga a pessoa de seu relacionamento (Art.33,§3º)',
                         'RUBRICA_A.I.-Porte de entorpecente (Art. 16)',
                         'RUBRICA_A.I.-Porte de objeto destinado à fabricação de entorpecente (Art. 13)',
                         'RUBRICA_A.I.-Roubo (art. 157)',
                         'RUBRICA_A.I.-Tráfico de entorpecente (Art. 12)',
                         'RUBRICA_Drogas sem autorização ou em desacordo (Art.33, caput)',
                         'RUBRICA_Estupro (art.213)',
                         'RUBRICA_Estupro de vulneravel (art.217-A)',
                         'RUBRICA_Furto (art. 155)',
                         'RUBRICA_Furto de coisa comum (art. 156)',
                         'RUBRICA_Furto qualificado (art. 155, §4o.)',
                         'RUBRICA_Homicídio culposo (art. 121, §3o.)',
                         'RUBRICA_Homicídio culposo na direção de veículo automotor (Art. 302)',
                         'RUBRICA_Homicídio qualificado (art. 121, §2o.)',
                         'RUBRICA_Homicídio simples (art. 121)',
                         'RUBRICA_Induzir, instigar ou auxiliar alguém ao uso indevido de droga(Art.33,§2º)',
                         "RUBRICA_Lesão corporal  de natureza 'GRAVÍSSIMA' (art. 129, §2o.)",
                         'RUBRICA_Lesão corporal (art 129 § 9º)',
                         'RUBRICA_Lesão corporal (art. 129)',
                         'RUBRICA_Lesão corporal culposa (art. 129. §6o.)',
                         'RUBRICA_Lesão corporal culposa na direção de veículo automotor (Art. 303)',
                         'RUBRICA_Lesão corporal de natureza GRAVE (art. 129, §1o.)',
                         'RUBRICA_Lesão corporal seguida de morte (art. 129, §3o.)',
                         'RUBRICA_Oferecer droga a pessoa de seu relacionamento (Art.33,§3º)',
                         'RUBRICA_Porte de entorpecente (Art. 16)',
                         'RUBRICA_Roubo (art. 157)',
                          'RUBRICA_Tráfico de entorpecente (Art. 12)'])


filename = './df_13_16.sav'
f = open(filename, 'wb')
Pickler(f).dump(df)
f.close()

# %%
df.shape
# Out:
# (48, 7)

# %%
df.head()
# Out:
#         DATA    FURTO    ROUBO  HOMICÍDIO  LESAO CORPORAL  ESTUPRO  TRÁFICO
# 0 2013-01-01  38935.0  61321.0     2703.0         27269.0   1741.0   4641.0
# 1 2013-02-01  36462.0  58021.0     2371.0         29533.0   1761.0   4925.0
# 2 2013-03-01  42604.0  66917.0     2833.0         34242.0   1685.0   5279.0
# 3 2013-04-01  41338.0  65578.0     2643.0         31201.0   1503.0   5160.0
# 4 2013-05-01  42233.0  65606.0     2532.0         31592.0   1612.0   5504.0

# %%
plt.figure(figsize=(15,7))
plt.plot(df['ROUBO'], color = 'red', label = 'Roubo')
plt.plot(df['FURTO'], color = 'purple', label = 'Furto')
plt.plot(df['HOMICÍDIO'], color = 'pink', label = 'Homicídio')
plt.plot(df['ESTUPRO'], color = 'blue', label = 'Estupro')
plt.plot(df['TRÁFICO'], color = 'green', label = 'Tráfico')
plt.plot(df['LESAO CORPORAL'], color = 'yellow', label = 'Lesão Corporal')
plt.title('Crime rates')
plt.xlabel('Time')
plt.xticks(np.arange(36), df['DATA'], rotation=90)
plt.ylabel('Ocorrências por mês')
plt.legend()
plt.show()

# %%
print(df.shape)
df.head()
# Out:
# (48, 7)
#         DATA    FURTO    ROUBO  HOMICÍDIO  LESAO CORPORAL  ESTUPRO  TRÁFICO
# 0 2013-01-01  38935.0  61321.0     2703.0         27269.0   1741.0   4641.0
# 1 2013-02-01  36462.0  58021.0     2371.0         29533.0   1761.0   4925.0
# 2 2013-03-01  42604.0  66917.0     2833.0         34242.0   1685.0   5279.0
# 3 2013-04-01  41338.0  65578.0     2643.0         31201.0   1503.0   5160.0
# 4 2013-05-01  42233.0  65606.0     2532.0         31592.0   1612.0   5504.0

# %%
df.reset_index()
# Out:
#     index       DATA    FURTO    ROUBO  HOMICÍDIO  LESAO CORPORAL  ESTUPRO  \
# 0       0 2010-01-01  33356.0  54358.0     2592.0         28608.0   1648.0
# 1       1 2010-02-01  30819.0  51905.0     2330.0         27317.0   1461.0
# 2       2 2010-03-01  35983.0  59073.0     2566.0         30810.0   1411.0
# 3       3 2010-04-01  33948.0  56141.0     2458.0         28741.0   1293.0
# 4       4 2010-05-01  36222.0  58404.0     2431.0         29500.0   1425.0
# 5       5 2010-06-01  34475.0  55878.0     1938.0         28169.0   1436.0
# 6       6 2010-07-01  34940.0  57576.0     2204.0         26862.0   1447.0
# 7       7 2010-08-01  36170.0  56146.0     2093.0         30499.0   1506.0
# 8       8 2010-09-01  35578.0  53764.0     2045.0         28837.0   1546.0
# 9       9 2010-10-01  37472.0  58274.0     2185.0         31095.0   1476.0
# 10     10 2010-11-01  35561.0  55720.0     2307.0         29252.0   1443.0
# ...

# %%
### concatenate 10-12 com 13-16
df_10_12 = get_samples('df_10_12.sav')
df_13_16 = get_samples('df_13_16.sav')
df_10_16 = pd.concat([df_10_12, df_13_16])

df_10_16 = df_10_16.reset_index()

filename = './df_10_16.sav'
f = open(filename, 'wb')
Pickler(f).dump(df_10_16)
f.close()

# %%
df = df_10_16
plt.figure(figsize=(15,7))
plt.plot(df['ROUBO'], color = 'red', label = 'Roubo')
plt.plot(df['FURTO'], color = 'purple', label = 'Furto')
plt.plot(df['HOMICÍDIO'], color = 'pink', label = 'Homicídio')
plt.plot(df['ESTUPRO'], color = 'blue', label = 'Estupro')
plt.plot(df['TRÁFICO'], color = 'green', label = 'Tráfico')
plt.plot(df['LESAO CORPORAL'], color = 'yellow', label = 'Lesão Corporal')
plt.title('Crime rates')
plt.xlabel('Time')
plt.xticks(np.arange(84), df['DATA'].map(lambda x: x.strftime('%Y-%m')), rotation=90)
plt.ylabel('Ocorrências por mês')
plt.legend()
plt.show()
